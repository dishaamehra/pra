# %% [markdown]
# <a href="https://colab.research.google.com/github/dishaamehra/pra/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number =6
if(number%2==0):
  print("even")
# Out:
# even

# %% [markdown]
# analyze using python

# %%
import pandas as pd
df=pd.read_csv('data.csv')
print(df.describe())
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %% [markdown]
# visualize using matplotlib

# %%
import matplotlib.pyplot as plt
plt.plot(df['Duration'],df['Pulse'],marker='o',color='red')
plt.title('pulse rate')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
